# %%
#GGplot2 pesquisar no GIT DataSheet

# %%
#Lista todos datasheets do R bases
#data(packages = .packages(all.available = TRUE))
data()

# %%
#Padrão de plotagem
ggplot(data = <DATA>)+
    <GEOM_FUNCTION>(
        mapping=aes(<MAPPING>),
        stat = <STAT>,
        position = <POSITION>
    )+
    <COORDINATE_FUNCTION>+
    <FACET_FUNCTION> #dividir o grafico em subplots
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:15: '<' inesperado
# 1: #Padrão de plotagem
# 2: ggplot(data = <
#                  ^
# Traceback:

# %%
#SCATTERPLOT (Gráfico de dispersão)
library(tidyverse)
#displ: tamanho do motor de um carro em litros
#hwy: a eficiência de combustível de um caro na estrada em milhas por galão
ggplot(data = mpg) + geom_point(mapping = aes(x = displ, y=hwy))
# Out:
# plot without title

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
#Grafico de barras
ggplot(diamonds, aes(x=cut))+ geom_bar()
# Out:
# plot without title

# %%
#Tabbles são como dataframe mas com melhoria de produtividade
